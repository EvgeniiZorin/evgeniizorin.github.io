# %%
import os

from PIL import Image

# %%
# Out:
# ['essential-math-for-data-science.png',
#  'grokking-machine-learning.png',
#  'grokking-machine-learning_RESIZED.png',
#  'Learning-SQL-Alan-Beaulieu.jpg',
#  'learning-sql-oreily.png']

# %%
def resize_image(img_path: str, 
                 resize_to: tuple[int, int] = (300, 300)
                 ) -> None:
    # read image
    print(f'Image to resize: {img_path}')
    img = Image.open(img_path)
    before_img_size = img.size
    print(f' > Image size before resizing: {before_img_size}')
    
    # resize
    img = img.resize(resize_to)
    after_img_size = img.size
    print(f' > Image size after resizing: {after_img_size}')
    
    # save resized image
    resized_img_path = os.path.splitext(img_path)[0] + \
        '_RESIZED' + os.path.splitext(img_path)[1]
    img.save(resized_img_path)
    print(f' > Resized image saved to: {resized_img_path}\n')
    return None

DIRECTORY_WITH_IMAGES = '../images/cpd_books'
for i in [j for j in os.listdir(DIRECTORY_WITH_IMAGES) if 'RESIZED' not in j]:
    resize_image(f"{DIRECTORY_WITH_IMAGES}/{i}",
                (300,300)
                )
# Out:
# Image to resize: ../images/cpd_books/essential-math-for-data-science.png
#  > Image size before resizing: (719, 943)
#  > Image size after resizing: (300, 300)
#  > Resized image saved to: ../images/cpd_books/essential-math-for-data-science_RESIZED.png
#
# Image to resize: ../images/cpd_books/grokking-machine-learning.png
#  > Image size before resizing: (705, 888)
#  > Image size after resizing: (300, 300)
#  > Resized image saved to: ../images/cpd_books/grokking-machine-learning_RESIZED.png
#
# Image to resize: ../images/cpd_books/Learning-SQL-Alan-Beaulieu.jpg
#  > Image size before resizing: (1143, 1500)
#  > Image size after resizing: (300, 300)
#  > Resized image saved to: ../images/cpd_books/Learning-SQL-Alan-Beaulieu_RESIZED.jpg
#
# Image to resize: ../images/cpd_books/learning-sql-oreily.png
#  > Image size before resizing: (1143, 1500)
#  > Image size after resizing: (300, 300)
#  > Resized image saved to: ../images/cpd_books/learning-sql-oreily_RESIZED.png
#
# Image to resize: ../images/cpd_books/practical-statistics-for-data-scientists.png
#  > Image size before resizing: (762, 1000)
#  > Image size after resizing: (300, 300)
#  > Resized image saved to: ../images/cpd_books/practical-statistics-for-data-scientists_RESIZED.png
#
# Image to resize: ../images/cpd_books/statquest_ml.png
#  > Image size before resizing: (1360, 1360)
#  > Image size after resizing: (300, 300)
#  > Resized image saved to: ../images/cpd_books/statquest_ml_RESIZED.png
#
# Image to resize: ../images/cpd_books/storytelling-with-data.png
#  > Image size before resizing: (803, 1000)
#  > Image size after resizing: (300, 300)
#  > Resized image saved to: ../images/cpd_books/storytelling-with-data_RESIZED.png
